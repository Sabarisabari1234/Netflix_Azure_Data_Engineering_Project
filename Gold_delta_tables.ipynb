# %%
import dlt
from typing import Dict

# %%
@dlt.table(
    name = "goldnetflix_category"
)


def my_func():
    df = spark.readStream.format("delta").load("abfss://sliver@deprojectstorage0.dfs.core.windows.net/netflix_category")
    return df

# %%
@dlt.table(
    name = "goldnetflix_cast"
)


def my_func():
    df = spark.readStream.format("delta").load("abfss://sliver@deprojectstorage0.dfs.core.windows.net/netflix_cast")
    return df

# %%
@dlt.table(
    name = "goldnetflix_countries"
)


def my_func():
    df = spark.readStream.format("delta").load("abfss://sliver@deprojectstorage0.dfs.core.windows.net/netflix_countries")
    return df

# %%
@dlt.table(
    name = "goldnetflix_directors"
)


def my_func():
    df = spark.readStream.format("delta").load("abfss://sliver@deprojectstorage0.dfs.core.windows.net/netflix_directors")
    return df

# %%
@dlt.table


def gold_stg_netflix_titles():
    df = spark.readStream.format("delta").load("abfss://sliver@deprojectstorage0.dfs.core.windows.net/netflix_directors")
    return df

# %%
from pyspark.sql.functions import *

# %%
@dlt.view

def gold_trans_netflix_titles():
    df = spark.readStream.table("LIVE.gold_stg_netflix_titles")
    df = df.withColumn("new_flag", lit(1))
    return df

# %%
@dlt.table


def gold_netflix_titles():
    df = spark.readStream.table("LIVE.gold_trans_netflix_titles")
    return df
